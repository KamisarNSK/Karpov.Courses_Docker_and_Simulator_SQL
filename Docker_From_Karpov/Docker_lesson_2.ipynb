# %% [markdown]
# # 2 УРОК ПЕРВЫЙ КОНТЕЙНЕР

# %% [markdown]
# > Команды
# Работа с образами
# docker images или docker image ls — посмотреть список образов (ссылка, ссылка)
#
# docker rmi <образ> [образ...] или docker image rm <образ> [образ...] — удалить образ(ы) (ссылка, ссылка)
#
# Работа с контейнерами
# docker run <образ> — поднять контейнер на основе образа (ссылка)
#
#       docker run --name <имя> <образ> — при поднятии присвоить имя контейнеру (ссылка)
#
#       docker run --rm <образ> — удалять контейнер после завершения его работы (ссылка)
#
#       docker run -it <образ> — позволяет «войти» в контейнер во время его создания (ссылка, ссылка)
#
#       docker run -d <образ> — поднять контейнер в фоновом режиме (ссылка)
#
# docker ps — список активных (работающих) контейнеров (ссылка)
#
#       docker ps -a — список всех контейнеров (ссылка)
#
# docker stop <контейнер> [контейнер...] — остановить работающий(ие) контейнер(ы) (ссылка)
#
# docker start <контейнер> [контейнер...] — запустить остановленный(ые) контейнер(ы) (ссылка)
#
# docker rm <контейнер> [контейнер...] — удалить контейнер(ы) (ссылка)
#
# docker exec <контейнер> команда — запустить команду в работающем контейнер (ссылка)
#
#       docker exec -it <контейнер> bash — запустить bash процесс и «войти» в контейнер (ссылка)

# %% [markdown]
# ## > Задание 1
# Как вы знаете, вход в программирование начинается с приветствия миру (Hello, world)!
#
# А что насчет знакомства с докером? 🤔
#
# Зайдите на сайт Docker Hub (https://hub.docker.com/) и попробуйте найти там официальный
# образ hello world.
#
# Если найдете такой, скопируйте ссылку на этот образ и вставьте в качестве ответа.
#
# Если такого официального образа нет, напишите в ответе Такого нет.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 2
# Давайте немного походим по сайту Docker Hub (https://hub.docker.com/).
#
# Зайдите на сайт Docker Hub и найдите там официальный образ языка программирования Go.
#
# Найдите на сайте тег latest.
#
# Вы увидите плашку, где указаны DIGEST, OS/ARCH и COMPRESSED SIZE.
#
# Для тега latest вам нужно найти хеш образа для архитектуры linux/amd64.
#
#
#
# Архитектуру вы увидите в колонке OS/ARCH, а сам хеш — в колонке DIGEST.
#
# Вставьте в поле ответа найденный хеш.

# %% [markdown]
# ##### ОТВЕТ:

# %% [markdown]
# sha256:a0b51fe882f269828b63e7f69e6925f85afc548cf7cf967ecbfbcce6afe6f235

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 3
# Давайте теперь поработаем с образами.
#
# Напишите команду, которая выведет список образов.
#
# Опции указывать не нужно.

# %% [markdown]
# ##### ОТВЕТ:

# %% [markdown]
# sudo docker images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 4
# Продолжаем смотреть на команды.
#
# Выберите те варианты, которые сработают без всякой ошибки.
#
# P.S. Для полного эффекта желательно, чтобы вы эти команды выполнили.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 5
# Перейдем к более сложному заданию.
#
# Перед вами слои некого образа (выводится через команду docker history):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Введите в ответ хеш этого образа (IMAGE ID).
#
# Да, ответ находится прямо на картинке :)
#
# P.S. Сверху находится самый последний слой.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 6
# Давайте теперь поработаем с контейнерами.
#
# Вы подняли контейнеры на основе разных образов:
#
# python
# nginx
# postgres
# redis
# golang
# node
# Вы указываете опцию --rm и фоновый режим (-d).
#
# ![image.png](attachment:image.png)
#
# (> /dev/null используется, чтобы не выводить ID контейнеров, так что можете не обращать на это внимание)
#
# В данном задании подразумевается, что вы прямо поднимаете эти контейнеры :)
#
# В качестве ответа введите 2 числа:
#
# Сколько у вас будет работающих (поднятых) контейнеров
# Сколько всего будет контейнеров (включая остановленные)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### пришлось в КС все это запустить)

# %% [markdown]
# ## > Задание 7
# Аналогичное задание, только теперь вы уже выполнили следующие команды:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# В качестве ответа также введите 2 числа:
#
# Сколько у вас будет работающих (поднятых) контейнеров
#
# Сколько всего будет контейнеров (включая остановленные)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### повторил команды. потом sudo docker ps и sudo docker ps -a

# %% [markdown]
# ## > Задание 8
# Вы подняли 2 контейнера. Один на основе образа ubuntu, второй — redis.
#
# ![image.png](attachment:image.png)
#
# Что будет, если вы попробуете их удалить?
#
# То есть выполните команду docker rm ubuntu redis.
#
# docker rm ubuntu redis
#
#
# P.S. В этой команде не используются никакие опции.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### повторил команды. потом sudo docker ps и sudo docker ps -a

# %% [markdown]
# ## > Задание 9
# Скачайте образ kcoursedocker/task-2.9.
#
# Там работает программа, которая ждет ввода некого значения.
#
# Вам нужно ввести строку Get answer и нажать Enter.
#
# Полученный результат вставьте в качестве ответа

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Чтоб войти в контейнер
# ###### sudo docker run  -it kcoursedocker/task-2.9

# %% [markdown]
# ## > Задание 10
# Вы выполнили команду для поднятия контейнера на основе образа ubuntu:
#
# ![image.png](attachment:image.png)
#
# Что произойдет, когда вы выполните команду docker exec -it ubuntu bash?
#
# docker exec -it ubuntu bash

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 11
# Скачайте образ nginx'а с тегом 1.23 (nginx:1.23). О том, что это такое, мы поговорим в 7-м уроке :)
#
# Поднимите контейнер на основе этого образа.
#
# В самом контейнере вам нужно найти файл, который лежит по пути
# /etc/nginx/conf.d/default.conf.
#
# В этом файле вам нужно найти настройку server_name (при помощи, например, утилит cat или grep).
# Она находится в секции server.
#
# Выглядеть это будет следующим образом:
#
# server {
#     listen       80;
#     server_name  ответ;
#
#     #access_log  /var/log/nginx/host.access.log  main;
#
#     location / {
#         root   /usr/share/nginx/html;
#         index  index.html index.htm;
#     }
# . . .
#
#
# Вставьте в ответ значение, которое используется в директиве server_name.
#
# P.S. При поднятии контейнера не забудьте использовать фоновый (detach) режим.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### ОТВЕТ:

# %%
docker run --rm -d --name nginx nginx:1.23
docker exec -it nginx bash
cat /etc/nginx/conf.d/default.conf | grep server_name

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## > Задание 12
# Вы взяли 3 образа Go:
#
# golang:1.18
# golang:1
# golang:latest
#
# ![image.png](attachment:image.png)
#
# Что произойдет после выполнения команды:
#
# docker rmi $(echo $(docker images --format '{{.Repository}}:{{.Tag}}' | grep golang | grep -v golang:latest))
#
#
# Ссылка на grep https://losst.ru/gerp-poisk-vnutri-fajlov-v-linux#Синтаксис_grep

# %% [markdown]
# ##### ОТВЕТ:

# %% [markdown]
# ###### Что произойдет после выполнения команды:
#
# docker rmi $(echo $(docker images --format '{{.Repository}}:{{.Tag}}' | grep golang | grep -v golang:latest))
#
# В данном случае можно попробовать выполнить эту команду по частям.
#
# docker images --format '{{.Repository}}:{{.Tag}}' — выводим все образы в формате <репозиторий>:<тег>
# docker images --format '{{.Repository}}:{{.Tag}}' | grep golang — затем передаем это в команду grep, осуществляя поиск по golang.
# docker images --format '{{.Repository}}:{{.Tag}}' | grep golang | grep -v golang:latest — затем фильтруем образы golang, причем указываем все, кроме тега lates.
# полученные значения из п.3 передаются в команду echo (вывести на печать)
# полученные значения из п.4 передаются в команду docker rmi
#  В результате останется только образ golang:latest.

# %% [markdown]
# ![image.png](attachment:image.png)
